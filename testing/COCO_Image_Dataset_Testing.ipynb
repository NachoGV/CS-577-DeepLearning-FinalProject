# %% [markdown]
# # COCO Image Dataset Testing
#
# ## Imports

# %%
# Add Utils to path
import sys
sys.path.append('../Utils')  # Adds higher directory to python modules path.

# Utils
from datasets_generators import CocoDetection
from plot_coco_image import plot_coco_image

# Pytorch
from transformers import DetrImageProcessor

# %% [markdown]
# ## Load Data

# %%
# Paths
imgs_path = "../ExDark_All/Images"
coco_path = "../ExDark_COCO/train_set.json"

# Transforms
image_processor = DetrImageProcessor.from_pretrained("facebook/detr-resnet-50")

# COCO Dataset
coco_dataset = CocoDetection(image_directory_path=imgs_path,  annotation_file_path=coco_path, image_processor=image_processor)

# Data
print("Number of images: ", len(coco_dataset))
print("Number of classes: ", len(coco_dataset.coco.getCatIds()))
# Out:
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ignac\OneDrive\Documents\Master_IIT\CS-577-DL\Project\CS-577-DeepLearning-FinalProject\Testing\COCO Image Dataset Testing.ipynb Cell 4 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/ignac/OneDrive/Documents/Master_IIT/CS-577-DL/Project/CS-577-DeepLearning-FinalProject/Testing/COCO%20Image%20Dataset%20Testing.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> image_processor = DetrImageProcessor.from_pretrained("facebook/detr-resnet-50")
#       <a href='vscode-notebook-cell:/c%3A/Users/ignac/OneDrive/Documents/Master_IIT/CS-577-DL/Project/CS-577-DeepLearning-FinalProject/Testing/COCO%20Image%20Dataset%20Testing.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> # COCO Dataset
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ignac/OneDrive/Documents/Master_IIT/CS-577-DL/Project/CS-577-DeepLearning-FinalProject/Testing/COCO%20Image%20Dataset%20Testing.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> coco_dataset = CocoDetection(image_directory_path=imgs_path,  annotations_file_path=coco_path, image_processor=image_processor)
#      <a href='vscode-notebook-cell:/c%3A/Users/ignac/OneDrive/Documents/Master_IIT/CS-577-DL/Project/CS-577-DeepLearning-FinalProject/Testing/COCO%20Image%20Dataset%20Testing.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> # Data
#      <a href='vscode-notebook-cell:/c%3A/Users/ignac/OneDrive/Documents/Master_IIT/CS-577-DL/Project/CS-577-DeepLearning-FinalProject/Testing/COCO%20Image%20Dataset%20Testing.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> print("Number of images: ", len(coco_dataset))
#
# TypeError: __init__() got an unexpected keyword argument 'annotations_file_path'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Plots

# %%
# Randomly plot an image
plot_coco_image(coco_dataset, imgs_path)
# Out:
# Image ID:  5768 Image:  2015_05767.jpg
#
# Annotations:
# {'id': 16650, 'image_id': 5768, 'category_id': 9, 'bbox': ['283', '271', '25', '40']} Category Label:  Motorbike
# {'id': 16651, 'image_id': 5768, 'category_id': 9, 'bbox': ['427', '280', '50', '54']} Category Label:  Motorbike
# {'id': 16652, 'image_id': 5768, 'category_id': 9, 'bbox': ['588', '285', '46', '79']} Category Label:  Motorbike
# {'id': 16653, 'image_id': 5768, 'category_id': 9, 'bbox': ['35', '310', '142', '87']} Category Label:  Motorbike
# {'id': 16654, 'image_id': 5768, 'category_id': 10, 'bbox': ['25', '249', '30', '131']} Category Label:  People
# {'id': 16655, 'image_id': 5768, 'category_id': 10, 'bbox': ['63', '251', '62', '141']} Category Label:  People
# {'id': 16656, 'image_id': 5768, 'category_id': 10, 'bbox': ['128', '248', '63', '148']} Category Label:  People
# {'id': 16657, 'image_id': 5768, 'category_id': 10, 'bbox': ['195', '244', '37', '94']} Category Label:  People
# {'id': 16658, 'image_id': 5768, 'category_id': 10, 'bbox': ['315', '255', '22', '51']} Category Label:  People
# {'id': 16659, 'image_id': 5768, 'category_id': 10, 'bbox': ['285', '256', '20', '36']} Category Label:  People
# {'id': 16660, 'image_id': 5768, 'category_id': 10, 'bbox': ['355', '258', '21', '28']} Category Label:  People
# {'id': 16661, 'image_id': 5768, 'category_id': 10, 'bbox': ['441', '258', '23', '41']} Category Label:  People
# {'id': 16662, 'image_id': 5768, 'category_id': 10, 'bbox': ['400', '273', '31', '40']} Category Label:  People
# {'id': 16663, 'image_id': 5768, 'category_id': 10, 'bbox': ['527', '245', '44', '106']} Category Label:  People
# {'id': 16664, 'image_id': 5768, 'category_id': 10, 'bbox': ['577', '269', '31', '29']} Category Label:  People
# {'id': 16665, 'image_id': 5768, 'category_id': 10, 'bbox': ['604', '257', '33', '78']} Category Label:  People
# {'id': 16666, 'image_id': 5768, 'category_id': 9, 'bbox': ['339', '276', '19', '33']} Category Label:  Motorbike
# {'id': 16667, 'image_id': 5768, 'category_id': 4, 'bbox': ['228', '258', '26', '27']} Category Label:  Car
# {'id': 16668, 'image_id': 5768, 'category_id': 4, 'bbox': ['257', '260', '27', '24']} Category Label:  Car
