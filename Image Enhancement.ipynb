# 2015_02291.JPG
# 2015_02292.jpg
# 2015_02293.jpg
# 2015_02294.jpg
# 2015_02295.jpg
# 2015_02296.jpg
# 2015_02297.jpg
# 2015_02298.jpg
# 2015_02299.jpg
# 2015_02300.jpg
# 2015_02301.jpg
# 2015_02302.jpg
# 2015_02303.jpg
# 2015_02304.jpg
# 2015_02305.jpg
# 2015_02306.jpg
# 2015_02307.jpg
# 2015_02308.jpg
# 2015_02309.png
# 2015_02310.jpg
# 2015_02311.jpg
# 2015_02312.jpg
# 2015_02313.jpg
# 2015_02314.jpg
# 2015_02315.jpg
# 2015_02316.jpg
# 2015_02317.jpg
# 2015_02318.jpg
# 2015_02319.jpg
# 2015_02320.jpg
# 2015_02321.jpg
# 2015_02322.jpg
# 2015_02323.jpg
# 2015_02324.jpg
# 2015_02325.jpg
# 2015_02326.jpg
# 2015_02327.jpg
# 2015_02328.jpg
# 2015_02329.jpg
# 2015_02330.jpg
# 2015_02331.jpg
# 2015_02332.jpg
# 2015_02333.jpg
# 2015_02334.jpg
# 2015_02335.jpg
# 2015_02336.jpg
# 2015_02337.jpg
# 2015_02338.jpg
# 2015_02339.jpg
# 2015_02340.jpg
# 2015_02341.jpg
# 2015_02342.jpg
# 2015_02343.jpg
# 2015_02344.jpg
# 2015_02345.jpg
# 2015_02346.jpg
# 2015_02347.jpg
# 2015_02348.JPEG
# 2015_02349.JPEG
# 2015_02350.JPEG
# 2015_02351.JPEG
# 2015_02352.JPEG
# 2015_02353.JPEG
# 2015_02354.JPEG
# 2015_02355.JPEG
# 2015_02356.JPEG
# 2015_02357.JPEG
# 2015_02358.JPEG
# 2015_02359.JPEG
# 2015_02360.jpg
# 2015_02361.jpg
# 2015_02362.jpg
# 2015_02363.jpg
# 2015_02364.jpg
# 2015_02365.jpg
# 2015_02366.jpg
# 2015_02367.jpg
# 2015_02368.jpg
# 2015_02369.jpg
# 2015_02370.jpg
# 2015_02371.jpg
# 2015_02372.jpg
# 2015_02373.jpg
# 2015_02374.jpg
# 2015_02375.jpg
# 2015_02376.jpg
# 2015_02377.jpg
# 2015_02378.jpg
# 2015_02379.jpg
# 2015_02380.jpg
# 2015_02381.jpg
# 2015_02382.jpg
# 2015_02383.jpg
# 2015_02384.jpg
# 2015_02385.jpg
# 2015_02386.jpg
# 2015_02387.jpg
# 2015_02388.jpg
# 2015_02389.jpg
# 2015_02390.jpg
# 2015_02391.jpg
# 2015_02392.jpg
# 2015_02393.jpg
# 2015_02394.jpg
# 2015_02395.jpg
# 2015_02396.jpg
# 2015_02397.jpg
# 2015_02398.jpg
# 2015_02399.png
# 2015_02400.png
# 2015_02401.png
# 2015_02402.png
# 2015_02403.png
# 2015_02404.jpg
# 2015_02405.jpg

# %% [markdown]
# Histogram equalization

# %%
import cv2

# Load an RGB image
image = cv2.imread('Exdark/ExDark/Bus/2015_02353.JPEG')

# Convert the image to Lab color space
lab_image = cv2.cvtColor(image, cv2.COLOR_BGR2Lab)

# Split the Lab image into L, a, and b channels
l_channel, a_channel, b_channel = cv2.split(lab_image)

# Apply histogram equalization to the L channel
l_equalized = cv2.equalizeHist(l_channel)

# Merge the equalized L channel back with the original a and b channels
equalized_lab_image = cv2.merge((l_equalized, a_channel, b_channel))

# Convert the enhanced Lab image back to BGR color space
equalized_rgb_image = cv2.cvtColor(equalized_lab_image, cv2.COLOR_Lab2BGR)

# Display the original and equalized images
cv2.imshow('Original Image', image)
cv2.imshow('Equalized Image', equalized_rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# CLAHE

# %%
import cv2

# Load an RGB image
images = os.listdir("Exdark/ExDark/BUS")[:5]

for imgs in images:
    image = cv2.imread(f'Exdark/ExDark/Bus/{imgs}')

    # Convert the image to Lab color space
    lab_image = cv2.cvtColor(image, cv2.COLOR_BGR2Lab)

    # Split the Lab image into L, a, and b channels
    l_channel, a_channel, b_channel = cv2.split(lab_image)

    # Apply CLAHE (Contrast Limited Adaptive Histogram Equalization) to the L channel
    # cliplimit is 1 for LHE 
    clahe = cv2.createCLAHE(clipLimit = 2.5, tileGridSize=(8, 8))
    clipped_l_channel = clahe.apply(l_channel)

    # Merge the enhanced L channel back with the original a and b channels
    enhanced_lab_image = cv2.merge((clipped_l_channel, a_channel, b_channel))

    # Convert the enhanced Lab image back to BGR color space
    enhanced_rgb_image = cv2.cvtColor(enhanced_lab_image, cv2.COLOR_Lab2BGR)

    # Display the original and enhanced images
    cv2.imshow('Original Image', image)
    cv2.imshow('Enhanced Image', enhanced_rgb_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
import cv2
from skimage.metrics import structural_similarity as ssim
import numpy as np

# Calculate PSNR
psnr = cv2.PSNR(image, enhanced_rgb_image)
print(f"PSNR: {psnr} dB")

# Convert the images to grayscale for SSIM calculation
original_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
equalized_gray = cv2.cvtColor(enhanced_rgb_image, cv2.COLOR_BGR2GRAY)

# Calculate SSIM
ssim_value = ssim(original_gray, equalized_gray)
print(f"SSIM: {ssim_value}")
# Out:
# PSNR: 21.353031400306897 dB
# SSIM: 0.8202518849611398

# %%
image = cv2.imread('Exdark/ExDark/Bus/2015_02169.jpg')

# %% [markdown]
# COLOR BALANCE ADJUSTMENT

# %%
import cv2
import numpy as np

def color_balance_adjustment(image):
    # Convert the image to float to perform calculations
    image_float = image.astype(np.float32)

    # Calculate the scaling factors for each channel
    r_mean = np.mean(image_float[:, :, 0])
    g_mean = np.mean(image_float[:, :, 1])
    b_mean = np.mean(image_float[:, :, 2])

    k = (r_mean + g_mean + b_mean) / 3.0

    # Adjust each channel by multiplying it with the scaling factor
    r_channel = (image_float[:, :, 0] * k / (r_mean + 1e-10))
    g_channel = (image_float[:, :, 1] * k / (g_mean + 1e-10))
    b_channel = (image_float[:, :, 2] * k / (b_mean + 1e-10))

    # Merge the adjusted channels back into an RGB image
    adjusted_image = np.stack((r_channel, g_channel, b_channel), axis=-1)

    # Clip the values to be in the valid 0-255 range
    adjusted_image = np.clip(adjusted_image, 0, 255)

    return np.uint8(adjusted_image)

# Apply color balance adjustment to the RGB image
adjusted_image = color_balance_adjustment(image)

# Display the original and adjusted images
cv2.imshow('Original Image', image)
cv2.imshow('Adjusted Image', adjusted_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def min_max_contrast_enhancement(image):
    # Convert the image to a floating-point representation
    img_float = image.astype(np.float32)

    # Calculate the minimum and maximum intensity values for the entire image
    min_val = img_float.min()
    max_val = img_float.max()

    # Apply the Min-Max contrast enhancement to the entire image
    enhanced_image = 255 * (img_float - min_val) / (max_val - min_val)

    # Clip the values to the [0, 255] range
    enhanced_image = np.clip(enhanced_image, 0, 255)

    # Convert the image back to uint8 format
    enhanced_image = enhanced_image.astype(np.uint8)

    return enhanced_image

# Apply Min-Max contrast enhancement
enhanced_image = min_max_contrast_enhancement(image)

# Display the original and enhanced images
cv2.imshow('Original Image', image)
cv2.imshow('Enhanced Image', enhanced_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
